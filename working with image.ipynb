# %%
import matplotlib.pyplot as plt
from matplotlib import image

# %%
from PIL import Image

img = Image.open(r"C:\Users\Abinay Rachakonda\Downloads\meme_1.PNG")

# %%
plt.imshow(img)

# %%
text_1 = "Deep learning" 
text_2 = "complex alogrithms"
text_3 = "interns"
text_4 = "Basis ms-execl "
text_5 = "and problem solving"

# %%
from PIL import Image, ImageDraw, ImageFont

# %%
font_1 = ImageFont.truetype(r'C:\Users\Abinay Rachakonda\Downloads\Roboto\Roboto-Black.ttf', 40)
font_2 = ImageFont.truetype(r'C:\Users\Abinay Rachakonda\Downloads\Roboto\Roboto-Black.ttf', 50)
font_3 = ImageFont.truetype(r'C:\Users\Abinay Rachakonda\Downloads\Roboto\Roboto-Black.ttf', 30)

# %%
draw = ImageDraw.Draw(img)
draw.text((300,100), text_1,font=font_1,fill='darkblue')
draw.text((300,150), text_2,font=font_1,fill='darkblue')
draw.text((800, 150), text_3,font=font_2,fill=(255,255, 0))
draw.text((1050,100), text_4,font=font_3,fill='darkblue')
draw.text((1050,150), text_5,font=font_3,fill='darkblue')

plt.imshow(img)

# %%
# Exploring Built-in Color Names in PIL
from PIL import ImageColor

colors=ImageColor.colormap

print(colors)

# Hexcode representation of  colors
# Out:
# {'aliceblue': '#f0f8ff', 'antiquewhite': '#faebd7', 'aqua': '#00ffff', 'aquamarine': '#7fffd4', 'azure': '#f0ffff', 'beige': '#f5f5dc', 'bisque': '#ffe4c4', 'black': '#000000', 'blanchedalmond': '#ffebcd', 'blue': '#0000ff', 'blueviolet': '#8a2be2', 'brown': '#a52a2a', 'burlywood': '#deb887', 'cadetblue': '#5f9ea0', 'chartreuse': '#7fff00', 'chocolate': '#d2691e', 'coral': '#ff7f50', 'cornflowerblue': '#6495ed', 'cornsilk': '#fff8dc', 'crimson': '#dc143c', 'cyan': '#00ffff', 'darkblue': '#00008b', 'darkcyan': '#008b8b', 'darkgoldenrod': '#b8860b', 'darkgray': '#a9a9a9', 'darkgrey': '#a9a9a9', 'darkgreen': '#006400', 'darkkhaki': '#bdb76b', 'darkmagenta': '#8b008b', 'darkolivegreen': '#556b2f', 'darkorange': '#ff8c00', 'darkorchid': '#9932cc', 'darkred': '#8b0000', 'darksalmon': '#e9967a', 'darkseagreen': '#8fbc8f', 'darkslateblue': '#483d8b', 'darkslategray': '#2f4f4f', 'darkslategrey': '#2f4f4f', 'darkturquoise': '#00ced1', 'darkviolet': '#9400d3', 'deeppink': '#ff1493', 'deepskyblu
# ...

# %%
from PIL import Image

img = Image.open(r"C:\Users\Abinay Rachakonda\Downloads\meme_2.jpg")

plt.imshow(img)

# %%
text_1 = "listing kanav sir"
text_2 = "entire class"
text_3 = "but when kanav sir gives"
text_4 ="task,project,test,"
text_5 = "Quiz,assignments." 
text_6 =  "all class be like"

# %%
from PIL import Image, ImageDraw, ImageFont

# %%
font_1 = ImageFont.truetype(r'C:\Users\Abinay Rachakonda\Downloads\Roboto\Roboto-Black.ttf', 40)
font_2 = ImageFont.truetype(r'C:\Users\Abinay Rachakonda\Downloads\Roboto\Roboto-Black.ttf', 50)
font_3 = ImageFont.truetype(r'C:\Users\Abinay Rachakonda\Downloads\Roboto\Roboto-Black.ttf', 30)

# %%
draw = ImageDraw.Draw(img)
draw.text((650,800), text_1,font=font_2,fill=(0,0,0))
draw.text((650,850), text_2,font=font_2,fill=(0,0,0))
draw.text((610,250), text_3,font=font_2,fill=(0,0,0))
draw.text((610,300), text_4,font=font_2,fill=(0,0,0))
draw.text((610,350), text_5,font=font_2,fill=(0,0,0))
draw.text((610,400), text_6,font=font_2,fill=(0,0,0))

# %%
plt.imshow(img)
